# %% [markdown]
# # Pandas : Data Preprocessing
# - Also check : Pyspark, Dask, Mito, Polars, YoloPandas, PandasAI, pandas-profiling, vanna

# %% [markdown]
# ## Data Scientist
# - 1) Server : read/access data from server
# - 2) Local : access file through network, direct access

# %% [markdown]
# **data could be of different types:** <br>
# - Sql Database
# - Oracle Database
# - Mongodb ( json objects )
# - Firebase
# - txt
# - log file
# - pdf
# - word
# - xls, xlsx
# - csv ( comma seperated values ==> Ahmed, Mohamed, Ali)
# - json ( javascript object notation )
# - Live data

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\Admin\Desktop\Preprocessing\Pandas\tutorial pandas\nyc.csv")
data
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data.shape        #(row,column)
# Out:
# (31, 11)

# %%
data.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
data.columns.to_list()
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
list(data.columns)         #casting to data
# Out:
# ['EST',
#  'Temperature',
#  'DewPoint',
#  'Humidity',
#  'Sea Level PressureIn',
#  'VisibilityMiles',
#  'WindSpeedMPH',
#  'PrecipitationIn',
#  'CloudCover',
#  'Events',
#  'WindDirDegrees']

# %%
data.columns[0]
# Out:
# 'EST'

# %%
data.columns[1]
# Out:
# 'Temperature'

# %%
data['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
data[['Temperature']]
# Out:
#     Temperature
# 0            38
# 1            36
# 2            40
# 3            25
# 4            20
# 5            33
# 6            39
# 7            39
# 8            44
# 9            50
# 10           33
# 11           35
# 12           26
# 13           30
# 14           43
# 15           47
# 16           36
# 17           25
# 18           22
# 19           32
# 20           31
# 21           26
# 22           26
# 23           28
# 24           34
# 25           43
# 26           41
# 27           37
# 28           36
# 29           34
# 30           46

# %%
data[['Sea Level PressureIn']]
# Out:
#     Sea Level PressureIn
# 0                  30.03
# 1                  30.02
# 2                  29.86
# 3                  30.05
# 4                  30.57
# 5                  30.50
# 6                  30.28
# 7                  30.20
# 8                  30.16
# 9                  29.59
# 10                 29.92
# 11                 29.85
# 12                 29.94
# 13                 29.95
# 14                 29.82
# 15                 29.52
# 16                 29.78
# 17                 29.83
# 18                 30.03
# 19                 30.13
# 20                 30.15
# 21                 30.21
# 22                 29.77
# 23                 29.92
# 24                 30.25
# 25                 30.03
# 26                 30.03
# 27                 29.90
# 28                 29.58
# 29                 30.01
# 30                 29.90

# %%
data.Temperature.max()
# Out:
# np.int64(50)

# %%
data.Temperature.min()
# Out:
# np.int64(20)

# %%
data.Temperature.mean()        #int64--->take feature numpy
# Out:
# np.float64(34.67741935483871)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %%
data.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
data.Temperature.dtype        #memory usage: 2.8+ KB
# Out:
# dtype('int64')

# %%
data.Temperature.max()
# Out:
# np.int64(50)

# %%
data.Temperature=data.Temperature.astype('int8')

# %%
data.Temperature.dtype
# Out:
# dtype('int8')

# %%
data.info()          #memory usage: 2.6+ KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int8
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(5), int8(1), object(3)
# memory usage: 2.6+ KB

# %%
for i in data.Temperature:
  if i > 30:
    print(i)
# Out:
# 38
# 36
# 40
# 33
# 39
# 39
# 44
# 50
# 33
# 35
# 43
# 47
# 36
# 32
# 31
# 34
# 43
# 41
# 37
# 36
# 34
# 46

# %%
#count number days==rain
counter=0
for i in data.Events:
  if i == 'Rain':
    counter+=1
print(counter)
# Out:
# 4

# %%
data[data.Temperature>30]      #codition in pandas and return all columns
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# ...

# %%
data[data.Events=="Rain"]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
data[data.Temperature>40].Temperature
# Out:
# 8     44
# 9     50
# 14    43
# 15    47
# 25    43
# 26    41
# 30    46
# Name: Temperature, dtype: int8

# %%
data[data.Temperature>40]['Temperature']
# Out:
# 8     44
# 9     50
# 14    43
# 15    47
# 25    43
# 26    41
# 30    46
# Name: Temperature, dtype: int8

# %%
data[data.Temperature>40][['Temperature']]
# Out:
#     Temperature
# 8            44
# 9            50
# 14           43
# 15           47
# 25           43
# 26           41
# 30           46

# %%
data[data.Temperature>40][["EST"]]
# Out:
#           EST
# 8    1/9/2016
# 9   1/10/2016
# 14  1/15/2016
# 15  1/16/2016
# 25  1/26/2016
# 26  1/27/2016
# 30  1/31/2016

# %%
data[data.Temperature>40]["EST"].tolist()
# Out:
# ['1/9/2016',
#  '1/10/2016',
#  '1/15/2016',
#  '1/16/2016',
#  '1/26/2016',
#  '1/27/2016',
#  '1/31/2016']

# %%
len(data[data.Events=="Rain"])
# Out:
# 4

# %%
data[:]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
data[:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
data[10:23]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
#
# ...

# %%
data.head()         #return 5
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
data.tail()        #return last 5
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
data.head(7)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
# 6  1/7/2016           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# ...

# %%
data.tail(7)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 24               10           3.0               0           2    NaN
# 25               10           7.0               0           2    NaN
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# ...

# %%
data.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
online_data=pd.read_csv(r"https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv")       #dta from browser
online_data
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]
